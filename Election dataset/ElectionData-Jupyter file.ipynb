# %%
#Reference:https://stackoverflow.com/questions/12332975/installing-python-module-within-code
def install_and_import(package):
    import importlib
    try:
        importlib.import_module(package)
    except ImportError:
        import pip
        pip.main(['install', package])
    finally:
        globals()[package] = importlib.import_module(package)


install_and_import('plotly')
install_and_import('numpy')
install_and_import('pandas')
# install_and_import('matplotlib')
# install_and_import('sklearn')
# install_and_import('RadViz-Plotly')  this function doesn't work with the released packge

# !pip install -U scikit-learn scipy matplotlib
# !pip install RadViz-Plotly

# %% [markdown]
# ###  Election Dataset
# ### there are four graphs here one by parties classification and the other by territory Name, this is by territory Name and remove time dimension
# ### There are four graphs here one by parties classification and the other by territory Name

# %%
from radviz_plotly import RadViz2D
from radviz_plotly import RadViz3D
import pandas as pd
import time
import plotly.io as pio
pio.renderers.default='iframe'

# %%
data= pd.read_csv('ElectionData.csv')
y=data['territoryName']
X=data.drop(['territoryName','time','Party'], axis=1) 
BPs=10000
time_start = time.time()
RadViz3D(y,X,BPs)
print( 'RadViz3D done! Time elapsed: {} seconds'.format(time.time()-time_start))
# Out:
# RadViz3D done! Time elapsed: 4.08600378036499 seconds
